# %%
# working_location = os.chdir("/home/oikura/Desktop/synchronization/WORK/IT/Yulia/scripts")
# print ("Renaming files...")
# exec(open("./modules/renaming_files.py").read())
print ("Extracting and converting to WHAM format")
exec(open("./modules/ExtractImportExportPandas.py").read())
print ("Generating metadata")
exec(open("./modules/metadata_file_generator.py").read())
print ("Launching WHAM")
exec(open("./modules/wham_output_generator.py").read())
print ("Converting data to uiwham.x input")
exec(open("./modules/convertation_for_UIWHAM.py").read())
print ("Visualizing")
exec(open("./modules/MathplotlibPandasDfPlot.py").read())
# Out:
# Extracting and converting to WHAM format
# Finished convertation for WHAM, see files in ..%s/dist_out directories.
# Generating metadata
# Launching WHAM
# cd ../wham/wham && ./wham 1.8 8 150 0.01 300 0 ../../Li/dist_out/metadata_Li_dist_out ../../Li/dist_out/Li.out
#
#  Calculations for Li done.
#
# cd ../wham/wham && ./wham 1.8 8 150 0.01 300 0 ../../Na/dist_out/metadata_Na_dist_out ../../Na/dist_out/Na.out
#
#  Calculations for Na done.
#
# cd ../wham/wham && ./wham 1.8 8 150 0.01 300 0 ../../K/dist_out/metadata_K_dist_out ../../K/dist_out/K.out
#
#  Calculations for K done.
#
# cd ../wham/wham && ./wham 1.8 8 150 0.01 300 0 ../../Cs/dist_out/metadata_Cs_dist_out ../../Cs/dist_out/Cs.out
#
#  Calculations for Cs done.
#
# cd ../wham/wham && ./wham 1.8 8 150 0.01 300 0 ../../Rb/dist_out/metadata_Rb_dist_out ../../Rb/dist_out/Rb.out
#
#  Calculations for Rb done.
#
# Converting data to uiwham.x input
# /home/oikura/Desktop/synchronization/WORK/IT/Yulia/Li/dist  converting......
# ...

# %%
print (os.getcwd())
# Out:
# /home/oikura/Desktop/synchronization/WORK/IT/Yulia/scripts
