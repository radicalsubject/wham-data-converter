# %%
import os

working_location = os.chdir("/home/oikura/synchronization/IT/Yulia/") #перемещаемся в папку
working_location = os.getcwd()
print(working_location)

atom_list = ["Li", "Na", "K", "Cs", "Rb"]

for atom in atom_list:

##################################################################################################
# parameters #####################################################################################

    hist_min = 1
    hist_max = 10
    num_bins = 150
    tol = 0.01
    temperature = 300
    numpad = 0
    metadatafile = "/home/oikura/synchronization/IT/Yulia/%s/dist_out/metadata_%s_dist_out" % (atom, atom)
    freefile = "/home/oikura/synchronization/IT/Yulia/%s/dist_out/%s.out" % (atom, atom)
###################################################################################################
###################################################################################################


    terminal_command = 'cd ./wham/wham && ./wham %s %s %s %s %s %s %s %s' % (hist_min, hist_max, num_bins, tol, temperature, numpad, metadatafile, freefile)
    print (terminal_command)


    #чистим нычки: если в вашей фазе хода вы вытянули папку с файлом метаданных предыдущей версии, то удаляем ёё.
    if os.path.exists(os.getcwd() + "/%s/" % (atom) + "%s.out"):
        os.remove(os.getcwd() + "/%s/" % (atom) + "%s.out")

    print(os.popen(terminal_command).read()) # выполняем комманду в терминале запуская wham

    print ("ฅ(^・ﻌ・^)ฅ - miau, i love you!")
# Out:
# /home/oikura/synchronization/IT/Yulia
# cd ./wham/wham && ./wham 1 10 150 0.01 300 0 /home/oikura/synchronization/IT/Yulia/Li/dist_out/metadata_Li_dist_out /home/oikura/synchronization/IT/Yulia/Li/dist_out/Li.out
# # ./wham 1 10 150 0.01 300 0 /home/oikura/synchronization/IT/Yulia/Li/dist_out/metadata_Li_dist_out /home/oikura/synchronization/IT/Yulia/Li/dist_out/Li.out
# #Number of windows = 14
# # Dumping simulation biases, in the metadata file order
# # Window  F (free energy units)
# # 0	0.000000
# # 1	4.475294
# # 2	2.685413
# # 3	0.027098
# # 4	0.117942
# # 5	0.075794
# # 6	0.170836
# # 7	0.154444
# # 8	0.000000
# # 9	0.075794
# # 10	0.075794
# # 11	0.052323
# # 12	0.186118
# # 13	0.154444
# # No MC error analysis requested
#
# ฅ(^・ﻌ・^)ฅ - miau, i love you!
# cd ./wham/wham && ./wham 1 10 150 0.01 300 0 /home/oikura/synchronization/IT/Yulia/Na/dist_out/metadata_Na_dist_out /home/oikura/synchronization/IT/Yulia/Na/dist_out/Na.out
# # ./wham 1 10 150 0.01 300 0 /home/oikura/synchronization/IT/Yulia/Na/dist_out/metadata_Na_dist_out /home/oikura/synchronization/IT/Yulia/Na/dist_out/Na.out
# #Number of windows = 18
# # Dumping simulation biases, in the metadata file order
# # Window  F (free energy units)
# # 0	0.000000
# # 1	-0.209652
# # 2	1.829740
# # 3	-0.360717
# # 4	-0.091877
# # 5	-0.280574
# # 6	1.683299
# # 7	-0.043151
# # 8	1.683299
# # 9	-0.209652
# # 10	1.683299
# # 11	-0.280574
# # 12	-0.147065
# # 13	-0.071662
# # 14	-0.209652
# # 15	-0.280574
# # 16	0.000000
# # 17	-0.147065
# # No MC error analysis requested
#
# ฅ(^・ﻌ・^)ฅ - miau, i love you!
# cd ./wham/wham && ./wham 1 10 150 0.01 300 0 /home/oikura/synchronization/IT/Yulia/K/dist_out/metadata_K_dist_out /home/oikura/synchronization/IT/Yulia/K/dist_out/K.out
# # ./wham 1 10 150 0.01 300 0 /home/oikura/synchronization/IT/Yulia/K/dist_out/metadata_K_dist_out /home/oikura/synchronization/IT/Yulia/K/dist_out/K.out
# #Number of windows = 7
# # Dumping simulation biases, in the metadata file order
# # Window  F (free energy units)
# # 0	0.000000
# # 1	0.648603
# # 2	0.433741
# # 3	0.547611
# # 4	0.305430
# # 5	0.648603
# # 6	0.161242
# # No MC error analysis requested
#
# ฅ(^・ﻌ・^)ฅ - miau, i love you!
# cd ./wham/wham && ./wham 1 10 150 0.01 300 0 /home/oikura/synchronization/IT/Yulia/Cs/dist_out/metadata_Cs_dist_out /home/oikura/synchronization/IT/Yulia/Cs/dist_out/Cs.out
# # ./wham 1 10 150 0.01 300 0 /home/oikura/synchronization/IT/Yulia/Cs/dist_out/metadata_Cs_dist_out /home/oikura/synchronization/IT/Yulia/Cs/dist_out/Cs.out
# #Number of windows = 33
# #Iteration 10:  0.042347
# #Iteration 20:  0.003443
# # Dumping simulation biases, in the metadata file order
# # Window  F (free energy units)
# # 0	0.000000
# # 1	-0.110648
# # 2	-1.006488
# # 3	-0.110648
# # 4	-1.844114
# # 5	-5.961224
# # 6	-0.110648
# # 7	10.380744
# # 8	7.207590
# # 9	5.287574
# # 10	-0.110648
# # 11	-0.855213
# # 12	-2.086179
# # 13	0.150234
# # 14	0.077272
# # 15	-0.110648
# # 16	-0.673065
# # 17	0.000000
# # 18	0.000000
# # 19	-0.549313
# # 20	-0.435170
# # 21	-1.621395
# # 22	0.150234
# # 23	-5.961224
# # 24	-2.997211
# # 25	-1.171969
# # 26	-1.417235
# # 27	-5.965663
# # 28	13.526218
# # 29	-0.296005
# # 30	-2.997211
# # 31	-0.200143
# # 32	16.648273
# # No MC error analysis requested
#
# ฅ(^・ﻌ・^)ฅ - miau, i love you!
# cd ./wham/wham && ./wham 1 10 150 0.01 300 0 /home/oikura/synchronization/IT/Yulia/Rb/dist_out/metadata_Rb_dist_out /home/oikura/synchronization/IT/Yulia/Rb/dist_out/Rb.out
# # ./wham 1 10 150 0.01 300 0 /home/oikura/synchronization/IT/Yulia/Rb/dist_out/metadata_Rb_dist_out /home/oikura/synchronization/IT/Yulia/Rb/dist_out/Rb.out
# #Number of windows = 47
# #Iteration 10:  0.001739
# # Dumping simulation biases, in the metadata file order
# # Window  F (free energy units)
# # 0	0.000000
# # 1	-0.358119
# # 2	-0.358119
# # 3	-2.029393
# # 4	-0.189836
# # 5	-0.479097
# # 6	-0.037237
# # 7	-0.079860
# # 8	-0.129788
# # 9	-0.695727
# # 10	-0.079860
# # 11	-0.158326
# # 12	-0.158326
# # 13	-0.158326
# # 14	-0.695727
# # 15	-2.029393
# # 16	-0.264075
# # 17	-0.479097
# # 18	0.000000
# # 19	0.000000
# # 20	-0.358119
# # 21	-0.129788
# # 22	-0.189836
# # 23	-0.189836
# # 24	0.000000
# # 25	-0.189836
# # 26	-0.358119
# # 27	-2.029393
# # 28	-0.479097
# # 29	-0.189836
# # 30	-0.264075
# # 31	-0.037237
# # 32	-0.037237
# # 33	-0.158326
# # 34	-0.189836
# # 35	-0.264075
# # 36	-0.158326
# # 37	-0.079860
# # 38	-0.129788
# # 39	-0.264075
# # 40	-2.029393
# # 41	-0.264075
# # 42	-0.129788
# # 43	-0.308207
# # 44	-0.695727
# # 45	-0.308207
# # 46	0.000000
# # No MC error analysis requested
#
# ฅ(^・ﻌ・^)ฅ - miau, i love you!
