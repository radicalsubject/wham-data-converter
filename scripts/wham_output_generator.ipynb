# %%
import os

working_location = os.chdir("/home/oikura/Desktop/Yulia/")

working_location = os.getcwd()
current_working_location = os.chdir(working_location)
print (working_location)


atom_list = ["Li", "Na", "K", "Cs", "Rb"]

for atom in atom_list:

##################################################################################################
# parameters #####################################################################################

    hist_min = 1.8
    hist_max = 8
    num_bins = 150
    tol = 0.01
    temperature = 300
    numpad = 0
    metadatafile = "../../%s/dist_out/metadata_%s_dist_out" % (atom, atom)
    freefile = "../../%s/dist_out/%s.out" % (atom, atom)
###################################################################################################
###################################################################################################
    terminal_command = 'cd ./wham/wham && ./wham %s %s %s %s %s %s %s %s' % (hist_min, hist_max, num_bins, tol, temperature, numpad, metadatafile, freefile)
    print (terminal_command)

    #чистим нычки: если в вашей фазе хода вы вытянули папку с файлом предыдущей версии, то удаляем его.
    if os.path.exists(os.getcwd() + "/%s/" % (atom) + "%s.out"):
        os.remove(os.getcwd() + "/%s/" % (atom) + "%s.out")
    
    print(os.popen(terminal_command).read()) # выполняем комманду в терминале запуская wham
    os.chdir(working_location)
    print ("ฅ(^・ﻌ・^)ฅ - miau, i love you!")
# Out:
# /home/oikura/Desktop/synchronization/WORK/IT/Yulia
# cd ./wham/wham && ./wham 1.8 8 150 0.01 300 0 ../../Li/dist_out/metadata_Li_dist_out ../../Li/dist_out/Li.out
# # ./wham 1.8 8 150 0.01 300 0 ../../Li/dist_out/metadata_Li_dist_out ../../Li/dist_out/Li.out
# #Number of windows = 14
# #Iteration 10:  0.046162
# #Iteration 20:  0.009681
# # Dumping simulation biases, in the metadata file order
# # Window  F (free energy units)
# # 0	0.000000
# # 1	0.428507
# # 2	2.187441
# # 3	2.939981
# # 4	0.077093
# # 5	-0.086163
# # 6	1.141459
# # 7	3.941327
# # 8	0.000000
# # 9	1.249752
# # 10	2.187441
# # 11	0.428507
# # 12	0.428507
# # 13	8.086672
# # No MC error analysis requested
#
# ฅ(^・ﻌ・^)ฅ - miau, i love you!
# cd ./wham/wham && ./wham 1.8 8 150 0.01 300 0 ../../Na/dist_out/metadata_Na_dist_out ../../Na/dist_out/Na.out
# # ./wham 1.8 8 150 0.01 300 0 ../../Na/dist_out/metadata_Na_dist_out ../../Na/dist_out/Na.out
# #Number of windows = 18
# #Iteration 10:  0.017980
# # Dumping simulation biases, in the metadata file order
# # Window  F (free energy units)
# # 0	0.000000
# # 1	0.000000
# # 2	2.137556
# # 3	0.608902
# # 4	1.724417
# # 5	2.008719
# # 6	1.316903
# # 7	0.608902
# # 8	2.137556
# # 9	2.137556
# # 10	2.008719
# # 11	0.000000
# # 12	1.524929
# # 13	2.101229
# # 14	-0.284253
# # 15	-0.174764
# # 16	-0.284253
# # 17	-0.284253
# # No MC error analysis requested
#
# ฅ(^・ﻌ・^)ฅ - miau, i love you!
# cd ./wham/wham && ./wham 1.8 8 150 0.01 300 0 ../../K/dist_out/metadata_K_dist_out ../../K/dist_out/K.out
# # ./wham 1.8 8 150 0.01 300 0 ../../K/dist_out/metadata_K_dist_out ../../K/dist_out/K.out
# #Number of windows = 7
# #Iteration 10:  0.007114
# # Dumping simulation biases, in the metadata file order
# # Window  F (free energy units)
# # 0	0.000000
# # 1	-0.287482
# # 2	-0.923426
# # 3	0.394704
# # 4	-1.174304
# # 5	0.394704
# # 6	-0.564164
# # No MC error analysis requested
#
# ฅ(^・ﻌ・^)ฅ - miau, i love you!
# cd ./wham/wham && ./wham 1.8 8 150 0.01 300 0 ../../Cs/dist_out/metadata_Cs_dist_out ../../Cs/dist_out/Cs.out
# # ./wham 1.8 8 150 0.01 300 0 ../../Cs/dist_out/metadata_Cs_dist_out ../../Cs/dist_out/Cs.out
# #Number of windows = 33
# #Iteration 10:  0.112983
# #Iteration 20:  0.034473
# #Iteration 30:  0.011047
# #Iteration 40:  0.003612
# # Dumping simulation biases, in the metadata file order
# # Window  F (free energy units)
# # 0	0.000000
# # 1	0.414266
# # 2	-0.040958
# # 3	9.107785
# # 4	0.847984
# # 5	7.980485
# # 6	2.277256
# # 7	8.021064
# # 8	4.597942
# # 9	4.597942
# # 10	-0.610076
# # 11	3.583041
# # 12	6.334073
# # 13	6.334073
# # 14	-0.200659
# # 15	9.107785
# # 16	3.583041
# # 17	-0.341176
# # 18	4.597942
# # 19	2.199182
# # 20	3.583041
# # 21	-0.546839
# # 22	5.429205
# # 23	1.378028
# # 24	-0.581391
# # 25	3.583041
# # 26	-0.493498
# # 27	-0.100333
# # 28	2.872659
# # 29	0.223239
# # 30	4.868698
# # 31	3.583041
# # 32	8.021064
# # No MC error analysis requested
#
# ฅ(^・ﻌ・^)ฅ - miau, i love you!
# cd ./wham/wham && ./wham 1.8 8 150 0.01 300 0 ../../Rb/dist_out/metadata_Rb_dist_out ../../Rb/dist_out/Rb.out
# # ./wham 1.8 8 150 0.01 300 0 ../../Rb/dist_out/metadata_Rb_dist_out ../../Rb/dist_out/Rb.out
# #Number of windows = 47
# #Iteration 10:  0.058982
# #Iteration 20:  0.034851
# #Iteration 30:  0.021094
# #Iteration 40:  0.012935
# #Iteration 50:  0.007987
# #Iteration 60:  0.004951
# # Dumping simulation biases, in the metadata file order
# # Window  F (free energy units)
# # 0	0.000000
# # 1	4.285123
# # 2	2.703470
# # 3	2.703470
# # 4	-2.800989
# # 5	-1.249385
# # 6	-2.800989
# # 7	-0.463837
# # 8	1.665236
# # 9	-2.527133
# # 10	-0.463837
# # 11	-1.249385
# # 12	-0.463837
# # 13	-1.847307
# # 14	-2.800989
# # 15	0.513800
# # 16	-1.249385
# # 17	3.854017
# # 18	0.000000
# # 19	1.665236
# # 20	0.000000
# # 21	-1.547332
# # 22	0.513800
# # 23	0.513800
# # 24	3.854017
# # 25	3.854017
# # 26	-0.463837
# # 27	-1.547332
# # 28	4.285123
# # 29	-0.463837
# # 30	3.854017
# # 31	4.285123
# # 32	-1.847307
# # 33	0.000000
# # 34	2.703470
# # 35	-1.847307
# # 36	-1.249385
# # 37	3.854017
# # 38	1.665236
# # 39	-2.527133
# # 40	4.285123
# # 41	0.000000
# # 42	-2.527133
# # 43	-1.847307
# # 44	0.513800
# # 45	-1.249385
# # 46	-0.463837
# # No MC error analysis requested
#
# ฅ(^・ﻌ・^)ฅ - miau, i love you!
